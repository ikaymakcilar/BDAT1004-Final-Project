# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /Users/iremkaymakcilar/anaconda3/lib/python3.11/site-packages (4.6.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/iremkaymakcilar/anaconda3/lib/python3.11/site-packages (from pymongo) (2.4.2)

# %%
import requests
from datetime import datetime
from pymongo import MongoClient

import schedule
import time

def fetch_historical_data():
    url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=usd&days=90'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

def update_database_with_historical_data(db, data):
    if 'prices' in data:
        for entry in data['prices']:
            timestamp = entry[0]
            price = entry[1]
            date = datetime.fromtimestamp(timestamp / 1000.0)

            # Check if the data already exists in the collection
            existing_data = db.bitcoinHistoricalData.find_one({'date': date})

            if existing_data is None: 
                # Data does not exist, insert it into the collection
                db.bitcoinHistoricalData.insert_one({'date': date, 'price': price})
                print(f"Inserted new data for {date}")
            #else:
                #print(f"Data for {date} already exists, skipping")
        
        print("Database updated with historical data")
    else:
        print("No valid data found in the response")


def main():
    client = MongoClient("mongodb+srv://bdat1004:bdat1004@cluster0.wzablab.mongodb.net/?retryWrites=true&w=majority")
    db = client.bitcoinData

    print("Fetching historical data for Bitcoin")
    historical_data = fetch_historical_data()
    if historical_data:
        update_database_with_historical_data(db, historical_data)

if __name__ == "__main__":
    schedule.every().day.at("20:02").do(main)
    
    while True:
        schedule.run_pending()
        time.sleep(40)
# Out:
# Fetching historical data for Bitcoin
# Inserted new data for 2023-12-05 22:00:57.786000
# Inserted new data for 2023-12-05 23:00:51.849000
# Inserted new data for 2023-12-06 00:00:22.939000
# Inserted new data for 2023-12-06 01:00:37.215000
# Inserted new data for 2023-12-06 02:01:19.226000
# Inserted new data for 2023-12-06 03:00:00.590000
# Inserted new data for 2023-12-06 04:00:10.855000
# Inserted new data for 2023-12-06 05:00:06.473000
# Inserted new data for 2023-12-06 06:00:03.763000
# Inserted new data for 2023-12-06 07:00:42.135000
# Inserted new data for 2023-12-06 08:00:33.869000
# Inserted new data for 2023-12-06 09:00:05.627000
# Inserted new data for 2023-12-06 10:00:10.159000
# Inserted new data for 2023-12-06 11:00:17.153000
# Inserted new data for 2023-12-06 12:00:05.724000
# Inserted new data for 2023-12-06 13:00:03.341000
# Inserted new data for 2023-12-06 14:00:23.114000
# Inserted new data for 2023-12-06 15:00:14.214000
# Inserted new data for 2023-12-06 16:00:19.562000
# Inserted new data for 2023-12-06 17:00:11.308000
# Inserted new data for 2023-12-06 18:00:00.189000
# Inserted new data for 2023-12-06 19:00:07.579000
# Inserted new data for 2023-12-06 20:00:22.955000
# Inserted new data for 2023-12-06 21:00:29.262000
# Inserted new data for 2023-12-06 22:00:06.981000
# Inserted new data for 2023-12-06 23:00:12.594000
# Inserted new data for 2023-12-07 00:00:23.750000
# Inserted new data for 2023-12-07 01:00:59.311000
# Inserted new data for 2023-12-07 02:00:17.246000
# Inserted new data for 2023-12-07 03:00:28.612000
# Inserted new data for 2023-12-07 04:00:35.403000
# Inserted new data for 2023-12-07 05:01:05.221000
# Inserted new data for 2023-12-07 06:00:35.962000
# Inserted new data for 2023-12-07 07:00:07.793000
